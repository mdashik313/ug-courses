# %%
a = 5
print(a)
print("hello")
for i in range(0,a,1):
    print(i)
# Out:
# 5
# hello
# 0
# 1
# 2
# 3
# 4

# %%
var = input("enter an int: ")
print(var)
# Out:
# enter an int: asdlkf
# asdlkf

# %% [markdown]
# Task1

# %%
gender = input('enter gender(M or F): ')
height = int(input('enter height: '))

if gender=='M':
    if height == 166 :
        print('height is average')
    elif height > 166 :
        print('height is tall')
    else :
        print('short')
else :
    if height == 155 :
        print('height is average')
    elif height > 155 :
        print('height is tall')
    else :
        print('short')
# Out:
# enter gender(M or F): F
# enter height: 199
# height is tall

# %% [markdown]
# List

# %%
#empty list
l = []
l1 = [1,2,'ashik']
l1.append(3)
for i in l1:
    print(i)
print(l1[-1])
# Out:
# 1
# 2
# ashik
# ashik

# %%
list = [1,2,[5,6],7,8]
print(list[2][0]) #pritns 5

if 5 in list:
    print('found')
#sublist
sub = list[0:2]
for i in sub:
    print(i)
# Out:
# 5
# 1
# 2
