# %%
history = []
history.append(-0.3423423423)
history.append(4.1)
history.append(0.23423)
history.append(1)
history.append(.113)
history.append(.107)
history.append(.237)
history.append(.107)
history.append(.107)

import matplotlib.pyplot as plt

plt.plot(history)
plt.show()
