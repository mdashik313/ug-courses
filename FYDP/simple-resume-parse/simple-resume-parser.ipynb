# %%
pip install pymupdf

# %%
import fitz
my_path = '1692461034530.pdf'
doc = fitz.open(my_path)

for page in doc:

    text = page.get_text()

    print(text)
# Out:
# Niful Islam
# Ex- competitive programmer | Machine Learning Enthusiast
# (+88) 01838-574649
# nislam201057@bscse.uiu.ac.bd
# github
#  Bachelor in Computer Science and Engineering (major in Data Science)
# United International University
# CGPA : 3.73 (111.5/ 132.5 credits)
# Merit-based scholarship: 100% - 4 times, 50% - 2 times, 25% - 1 time
# January 2020- January 2024
# Education
# Computer Vision Projects
# Projects
# kaggle
# scholar
# Leetcode
# Garbage Image Classification with Swin transformer and attention based autoencoder (link)
# A fine-tuned autoencoder
# A Fusion model of Swin transformer and Autoencoder
# Bronze Medal on Kaggle with 60+ forks
# Painting Classifier with DenseNet121 using FastAI (link)
# Scrapped 10 types of Data from DuckDuckGo
# Classified using DenseNet121
# Model deployed on Huggingface and integrated on github pages through API
# Natural Language Processing Projects
# Multi-label IEEE Keyword Prediction with transformers (link)
# ...
